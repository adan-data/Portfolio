# %% [markdown]
# Agentic AI refers to artificial intelligence systems that can perceive their environment, make decisions, and act autonomously to achieve a goal. These agents typically use reinforcement learning (RL) methods to optimize their behaviour over time through interactions with an environment.

# %% [markdown]
# Understanding the Components of Agentic AI
# Agentic AI involves several key components. In this article, I’ll be building an AI Agent for trading. So, let’s understand the key components of Agentic AI with our example:
#
# 1. The Agent: The agent is the decision-making entity in the AI system. In our case, the DQN trading agent will be responsible for making trading decisions based on market data.
#
# 2. The Environment: The environment is the external system in which the agent operates. Our trading environment will consist of stock market data, where the agent will interact with price movements and execute trades.
#
# 3. The State: The state represents the information available to the agent at any given time. Our trading agent’s state includes the stock’s closing price, moving averages, and daily returns.
#
# 4. The Action Space: The action space defines what actions the agent can take. Our trading agent has three possible actions: Buy, Sell, and Hold.
#
# 5. The Reward Function: The reward function determines the agent’s performance by assigning a numerical value to its actions. The goal of our trading agent will be to maximize total profit by the end of the trading session.
# Having this knowledge will help you understand all the steps we will take further to build an AI Agent using Agentic AI.

# %% [markdown]
# Building an AI Agent using Agentic AI: Getting Started
#
# Now, let’s get started with building an AI Agent for trading using Agentic AI. I’ll first import all the necessary Python libraries and collect Apple’s stock market data from Yahoo Finance:

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# define stock symbol and time period
symbol = "AAPL"
start_date = "2020-01-01"
end_date = "2025-02-14"

# download historical data
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Now, we will calculate technical indicators that help the AI agent make better trading decisions:

# %%
# feature engineering
data['SMA_5'] = data['Close'].rolling(window=5).mean()
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['Returns'] = data['Close'].pct_change()

# %% [markdown]
# Now, let’s drop missing values and reset the index:

# %%
# drop NaN values and reset index
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Next, we will define the action space. The AI agent has three possible actions:
#
# * HOLD: Do nothing.
# * BUY: Purchase stocks.
# * SELL: Sell held stocks.

# %%
# define action space
ACTIONS = {0: "HOLD", 1: "BUY", 2: "SELL"}

# %% [markdown]
# This action space is used to train the reinforcement learning model.

# %% [markdown]
# Now, we will extract the State from the data:

# %%
# get state function
def get_state(data, index):
    return np.array([
        float(data.loc[index, 'Close']),
        float(data.loc[index, 'SMA_5']),
        float(data.loc[index, 'SMA_20']),
        float(data.loc[index, 'Returns'])
    ])

# %% [markdown]
# This function extracts the state representation from the dataset at a given time index. The state is an array containing:
#
# * Closing price
# * 5-day SMA
# * 20-day SMA
# * Daily return percentage
#
# This numerical representation of the stock market is fed into the AI model to make trading decisions.

# %% [markdown]
# Building The Trading Environment for our AI Agent
# We will now define a trading environment to interact with the Deep Q-Network (DQN) AI agent, which will allow it to learn how to trade stocks profitably:

# %%
# trading environment
class TradingEnvironment:
    def __init__(self, data):
        self.data = data
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0

    def reset(self):
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0
        return get_state(self.data, self.index)

    def step(self, action):
        price = float(self.data.loc[self.index, 'Close'])
        reward = 0

        if action == 1 and self.balance >= price:  # BUY
            self.holdings = self.balance // price
            self.balance -= self.holdings * price
        elif action == 2 and self.holdings > 0:  # SELL
            self.balance += self.holdings * price
            self.holdings = 0

        self.index += 1
        done = self.index >= len(self.data) - 1

        if done:
            reward = self.balance - self.initial_balance

        next_state = get_state(self.data, self.index) if not done else None
        return next_state, reward, done, {}

# %% [markdown]
# The environment is implemented as a class that simulates the stock market. It tracks the agent’s balance, holdings, and current market index, and it provides new states and rewards in response to the agent’s actions.

# %% [markdown]
# The Deep Q-Network (DQN)
# DQN is a neural network that approximates the Q-values for each state-action pair. We will now define the neural network architecture for our Deep Q-Network. It will be responsible for predicting the best trading actions based on the stock market state:

# %%
# deep q-network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# Here we built a Deep Q-Network using PyTorch to optimize stock trading decisions. The model features a three-layer neural network to predict trading actions, leveraging ReLU activation to enhance learning efficiency.
#
# It outputs Q-values, which the agent utilizes to determine the best action: buy, sell, or hold, based on market conditions.

# %% [markdown]
# The DQN Agent
#
# Now, we will implement the AI agent that learns how to trade stocks using Deep Q-Learning. The DQN Agent will interact with the trading environment, make trading decisions (BUY, SELL, HOLD), store experiences, and learn from past experiences to improve future decisions:

# %%
# DQN agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(list(ACTIONS.keys()))
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            target_tensor = self.model(state_tensor).clone().detach()
            target_tensor[0][action] = target

            self.optimizer.zero_grad()
            output = self.model(state_tensor)
            loss = self.criterion(output, target_tensor)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# So, we developed a Deep Q-Learning Agent to interact with the stock market environment to enhance its decision-making through Experience Replay, which stores and reuses past experiences for training. The agent effectively balances Exploration vs. Exploitation, taking random actions initially and making smarter decisions as learning progresses.
#
# Training is performed using batches of past experiences to refine the neural network’s performance. Additionally, a discount factor (gamma) is applied to weigh immediate and future rewards, to ensure long-term profitability.

# %% [markdown]
# Training the AI Agent
#
# Training involves running multiple episodes where the agent interacts with the environment, learns from experience, and updates its model. Let’s train the agent:

# %%
# train the agent
env = TradingEnvironment(data)
agent = DQNAgent(state_size=4, action_size=3)
batch_size = 32
episodes = 500
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

print("Training Complete!")
# Out:
# <ipython-input-5-3915787d8dfc>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# <ipython-input-5-3915787d8dfc>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# <ipython-input-5-3915787d8dfc>:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# <ipython-input-5-3915787d8dfc>:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# <ipython-input-6-71f231bc395a>:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Episode 1/500, Total Reward: -9851.041069030762
# Episode 2/500, Total Reward: -9963.885120391846
# Episode 3/500, Total Reward: -9809.630996704102
# Episode 4/500, Total Reward: -9829.623840332031
# Episode 5/500, Total Reward: 8273.40454864502
# Episode 6/500, Total Reward: -9935.863147735596
# Episode 7/500, Total Reward: -9870.634872436523
# Episode 8/500, Total Reward: -9799.81502532959
# Episode 9/500, Total Reward: 2879.4647674560547
# Episode 10/500, Total Reward: -9997.783958435059
# Episode 11/500, Total Reward: -9811.114051818848
# Episode 12/500, Total Reward: -9836.806972503662
# Episode 13/500, Total Reward: -9832.390850067139
# Episode 14/500, Total Reward: -9863.934589385986
# Episode 15/500, Total Reward: -9802.481014251709
# Episode 16/500, Total Reward: -9834.589267730713
# Episode 17/500, Total Reward: -9923.68325805664
# Episode 18/500, Total Reward: 12716.460441589355
# Episode 19/500, Total Reward: -9883.488872528076
# Episode 20/500, Total Reward: -9728.1106300354
# Episode 21/500, Total Reward: -9890.613468170166
# Episode 22/500, Total Reward: -9937.189804077148
# Episode 23/500, Total Reward: -9795.914073944092
# Episode 24/500, Total Reward: -9932.475303649902
# Episode 25/500, Total Reward: 3439.767276763916
# Episode 26/500, Total Reward: -9880.236152648926
# Episode 27/500, Total Reward: -9799.018321990967
# Episode 28/500, Total Reward: -9936.581809997559
# Episode 29/500, Total Reward: 11950.15966796875
# Episode 30/500, Total Reward: 2149.427001953125
# Episode 31/500, Total Reward: -9929.715576171875
# Episode 32/500, Total Reward: -9784.71895980835
# Episode 33/500, Total Reward: -9743.607948303223
# Episode 34/500, Total Reward: -9931.875644683838
# Episode 35/500, Total Reward: -9772.508041381836
# Episode 36/500, Total Reward: -9825.593940734863
# Episode 37/500, Total Reward: -9825.65805053711
# Episode 38/500, Total Reward: -9986.795719146729
# Episode 39/500, Total Reward: -9894.656757354736
# Episode 40/500, Total Reward: -9931.657173156738
# Episode 41/500, Total Reward: -9787.05652999878
# Episode 42/500, Total Reward: -9867.471168518066
# Episode 43/500, Total Reward: -9831.490154266357
# Episode 44/500, Total Reward: -9908.892883300781
# Episode 45/500, Total Reward: -9865.567249298096
# Episode 46/500, Total Reward: -9864.074810028076
# Episode 47/500, Total Reward: 3645.7597007751465
# Episode 48/500, Total Reward: -9931.263389587402
# Episode 49/500, Total Reward: 13659.156551361084
# Episode 50/500, Total Reward: 3464.8185081481934
# Episode 51/500, Total Reward: -9820.957050323486
# Episode 52/500, Total Reward: -9834.341526031494
# Episode 53/500, Total Reward: -9831.24617767334
# Episode 54/500, Total Reward: -9791.47742843628
# Episode 55/500, Total Reward: -9856.443603515625
# Episode 56/500, Total Reward: -9829.185939788818
# Episode 57/500, Total Reward: 5657.203510284424
# Episode 58/500, Total Reward: -9778.71397781372
# Episode 59/500, Total Reward: -9986.466594696045
# Episode 60/500, Total Reward: -9764.209350585938
# Episode 61/500, Total Reward: 11497.156341552734
# Episode 62/500, Total Reward: 6422.627700805664
# Episode 63/500, Total Reward: -9831.779479980469
# Episode 64/500, Total Reward: -9805.879894256592
# Episode 65/500, Total Reward: -9877.271987915039
# Episode 66/500, Total Reward: -9852.309875488281
# Episode 67/500, Total Reward: -9951.804107666016
# Episode 68/500, Total Reward: -9959.086223602295
# Episode 69/500, Total Reward: 1825.3083457946777
# Episode 70/500, Total Reward: -9773.81258392334
# Episode 71/500, Total Reward: -9846.620880126953
# Episode 72/500, Total Reward: -9810.653373718262
# Episode 73/500, Total Reward: -9778.804489135742
# Episode 74/500, Total Reward: -9768.568420410156
# Episode 75/500, Total Reward: -9785.27600479126
# Episode 76/500, Total Reward: 8039.446876525879
# Episode 77/500, Total Reward: 16397.795448303223
# Episode 78/500, Total Reward: -9885.49499130249
# Episode 79/500, Total Reward: -9870.123397827148
# Episode 80/500, Total Reward: -9826.555744171143
# Episode 81/500, Total Reward: 5105.877815246582
# Episode 82/500, Total Reward: -9857.850872039795
# Episode 83/500, Total Reward: -9839.516872406006
# Episode 84/500, Total Reward: -9861.930755615234
# Episode 85/500, Total Reward: -9878.59041595459
# Episode 86/500, Total Reward: -9879.935733795166
# Episode 87/500, Total Reward: -9878.957775115967
# Episode 88/500, Total Reward: -9944.138725280762
# Episode 89/500, Total Reward: -9860.149166107178
# Episode 90/500, Total Reward: -9960.746074676514
# Episode 91/500, Total Reward: -9942.94049835205
# Episode 92/500, Total Reward: 5270.486511230469
# Episode 93/500, Total Reward: 20476.59161376953
# Episode 94/500, Total Reward: -9875.183517456055
# Episode 95/500, Total Reward: -9886.360885620117
# Episode 96/500, Total Reward: 9467.731014251709
# Episode 97/500, Total Reward: 11860.396083831787
# Episode 98/500, Total Reward: -9876.583862304688
# Episode 99/500, Total Reward: -9847.000286102295
# Episode 100/500, Total Reward: -9990.61803817749
# Episode 101/500, Total Reward: -9789.319641113281
# Episode 102/500, Total Reward: -9840.151790618896
# Episode 103/500, Total Reward: -9855.55562210083
# Episode 104/500, Total Reward: 9233.593605041504
# Episode 105/500, Total Reward: -9927.53409576416
# Episode 106/500, Total Reward: -9886.749961853027
# Episode 107/500, Total Reward: 6441.448150634766
# Episode 108/500, Total Reward: -9953.873405456543
# Episode 109/500, Total Reward: -9816.223663330078
# Episode 110/500, Total Reward: -9781.331268310547
# Episode 111/500, Total Reward: -9925.465835571289
# Episode 112/500, Total Reward: 18160.833404541016
# Episode 113/500, Total Reward: -9991.755184173584
# Episode 114/500, Total Reward: -9926.653839111328
# Episode 115/500, Total Reward: -9940.197406768799
# Episode 116/500, Total Reward: -9848.067405700684
# Episode 117/500, Total Reward: -9826.204601287842
# Episode 118/500, Total Reward: 228.07291412353516
# Episode 119/500, Total Reward: -9760.59684753418
# Episode 120/500, Total Reward: -9845.192085266113
# Episode 121/500, Total Reward: -9815.37574005127
# Episode 122/500, Total Reward: 6257.851108551025
# Episode 123/500, Total Reward: -9768.896266937256
# Episode 124/500, Total Reward: -9870.232913970947
# Episode 125/500, Total Reward: -9810.854312896729
# Episode 126/500, Total Reward: -9857.215412139893
# Episode 127/500, Total Reward: -9918.211723327637
# Episode 128/500, Total Reward: -9942.701793670654
# Episode 129/500, Total Reward: -9744.457321166992
# Episode 130/500, Total Reward: -9808.10641860962
# Episode 131/500, Total Reward: -9844.16315460205
# Episode 132/500, Total Reward: -9820.127365112305
# Episode 133/500, Total Reward: -9851.80976486206
# Episode 134/500, Total Reward: -132.62814331054688
# Episode 135/500, Total Reward: -9879.97981262207
# Episode 136/500, Total Reward: -9832.154224395752
# Episode 137/500, Total Reward: -9826.99662399292
# Episode 138/500, Total Reward: -9874.69607925415
# Episode 139/500, Total Reward: 1721.2241706848145
# Episode 140/500, Total Reward: -9792.29440689087
# Episode 141/500, Total Reward: -9876.91902923584
# Episode 142/500, Total Reward: 2723.0948333740234
# Episode 143/500, Total Reward: 538.2509422302246
# Episode 144/500, Total Reward: 2773.6714515686035
# Episode 145/500, Total Reward: -9876.096073150635
# Episode 146/500, Total Reward: 6528.250953674316
# Episode 147/500, Total Reward: -9784.144374847412
# Episode 148/500, Total Reward: -9854.467761993408
# Episode 149/500, Total Reward: -9847.51547241211
# Episode 150/500, Total Reward: -9876.697052001953
# Episode 151/500, Total Reward: -9910.750080108643
# Episode 152/500, Total Reward: -9784.344604492188
# Episode 153/500, Total Reward: -9841.186031341553
# Episode 154/500, Total Reward: -9881.276584625244
# Episode 155/500, Total Reward: -9997.426414489746
# Episode 156/500, Total Reward: -9877.222579956055
# Episode 157/500, Total Reward: 9860.028903961182
# Episode 158/500, Total Reward: -9848.896110534668
# Episode 159/500, Total Reward: 3600.6200637817383
# Episode 160/500, Total Reward: -9810.434017181396
# Episode 161/500, Total Reward: 8266.85336303711
# Episode 162/500, Total Reward: -9863.275241851807
# Episode 163/500, Total Reward: -9859.139533996582
# Episode 164/500, Total Reward: -9991.579006195068
# Episode 165/500, Total Reward: -9913.074966430664
# Episode 166/500, Total Reward: -9816.260719299316
# Episode 167/500, Total Reward: -9765.216083526611
# Episode 168/500, Total Reward: 938.2374877929688
# Episode 169/500, Total Reward: -134.6595916748047
# Episode 170/500, Total Reward: -9808.307903289795
# Episode 171/500, Total Reward: -9943.886951446533
# Episode 172/500, Total Reward: -9865.402973175049
# Episode 173/500, Total Reward: -9824.971294403076
# Episode 174/500, Total Reward: -9837.877571105957
# Episode 175/500, Total Reward: -9823.671241760254
# Episode 176/500, Total Reward: 4062.7141876220703
# Episode 177/500, Total Reward: -9776.436233520508
# Episode 178/500, Total Reward: 7099.894836425781
# Episode 179/500, Total Reward: 4028.6036682128906
# Episode 180/500, Total Reward: -9839.23715209961
# Episode 181/500, Total Reward: 482.8161430358887
# Episode 182/500, Total Reward: -9913.55040359497
# Episode 183/500, Total Reward: -9841.293014526367
# Episode 184/500, Total Reward: -9848.808029174805
# Episode 185/500, Total Reward: -9854.90665435791
# Episode 186/500, Total Reward: -9800.805255889893
# Episode 187/500, Total Reward: -9973.637901306152
# Episode 188/500, Total Reward: -9859.948596954346
# Episode 189/500, Total Reward: 3083.7592544555664
# Episode 190/500, Total Reward: 9884.258529663086
# Episode 191/500, Total Reward: -9826.689826965332
# Episode 192/500, Total Reward: 1582.1534576416016
# Episode 193/500, Total Reward: -9769.726741790771
# Episode 194/500, Total Reward: -9918.821475982666
# Episode 195/500, Total Reward: -9996.531623840332
# Episode 196/500, Total Reward: -9851.648139953613
# Episode 197/500, Total Reward: -9782.716941833496
# Episode 198/500, Total Reward: -9871.166301727295
# Episode 199/500, Total Reward: 7999.823226928711
# Episode 200/500, Total Reward: -9762.579109191895
# Episode 201/500, Total Reward: -9741.710800170898
# Episode 202/500, Total Reward: -9925.538650512695
# Episode 203/500, Total Reward: -9743.74405670166
# Episode 204/500, Total Reward: -9863.54468536377
# Episode 205/500, Total Reward: 3869.5831413269043
# Episode 206/500, Total Reward: -9780.780540466309
# Episode 207/500, Total Reward: -9912.64737701416
# Episode 208/500, Total Reward: 1240.8298721313477
# Episode 209/500, Total Reward: 9254.024673461914
# Episode 210/500, Total Reward: -9844.236461639404
# Episode 211/500, Total Reward: -9942.652938842773
# Episode 212/500, Total Reward: -9840.10153579712
# Episode 213/500, Total Reward: -9756.710777282715
# Episode 214/500, Total Reward: 5693.8891677856445
# Episode 215/500, Total Reward: 4693.425395965576
# Episode 216/500, Total Reward: -9813.414501190186
# Episode 217/500, Total Reward: -9828.48641204834
# Episode 218/500, Total Reward: -9871.10344696045
# Episode 219/500, Total Reward: -9850.710357666016
# Episode 220/500, Total Reward: -9953.860538482666
# Episode 221/500, Total Reward: -9802.99292755127
# Episode 222/500, Total Reward: 21668.077198028564
# Episode 223/500, Total Reward: -9936.244594573975
# Episode 224/500, Total Reward: 1042.837890625
# Episode 225/500, Total Reward: -9976.40253829956
# Episode 226/500, Total Reward: -9891.370399475098
# Episode 227/500, Total Reward: -9871.94760131836
# Episode 228/500, Total Reward: -9895.702285766602
# Episode 229/500, Total Reward: 3558.993148803711
# Episode 230/500, Total Reward: -9827.482036590576
# Episode 231/500, Total Reward: -9986.020530700684
# Episode 232/500, Total Reward: -9840.157234191895
# Episode 233/500, Total Reward: -9938.265628814697
# Episode 234/500, Total Reward: -9777.732604980469
# Episode 235/500, Total Reward: -9990.73042678833
# Episode 236/500, Total Reward: 7610.960220336914
# Episode 237/500, Total Reward: 14236.72280883789
# Episode 238/500, Total Reward: -9986.11654663086
# Episode 239/500, Total Reward: -9948.938579559326
# Episode 240/500, Total Reward: -9982.462059020996
# Episode 241/500, Total Reward: -9895.136352539062
# Episode 242/500, Total Reward: -9777.893840789795
# Episode 243/500, Total Reward: -9828.114696502686
# Episode 244/500, Total Reward: -9808.53800201416
# Episode 245/500, Total Reward: -9817.786033630371
# Episode 246/500, Total Reward: -9844.820655822754
# Episode 247/500, Total Reward: 7983.760467529297
# Episode 248/500, Total Reward: -9922.288078308105
# Episode 249/500, Total Reward: -9976.997772216797
# Episode 250/500, Total Reward: 1318.2623329162598
# Episode 251/500, Total Reward: -9856.496437072754
# Episode 252/500, Total Reward: -9860.204399108887
# Episode 253/500, Total Reward: -9939.53602218628
# Episode 254/500, Total Reward: -9815.888084411621
# Episode 255/500, Total Reward: -9985.404048919678
# Episode 256/500, Total Reward: -9934.490409851074
# Episode 257/500, Total Reward: 1258.5264701843262
# Episode 258/500, Total Reward: -9984.296058654785
# Episode 259/500, Total Reward: -9920.957485198975
# Episode 260/500, Total Reward: -1386.6508979797363
# Episode 261/500, Total Reward: -1166.600170135498
# Episode 262/500, Total Reward: -1918.901870727539
# Episode 263/500, Total Reward: -9889.840732574463
# Episode 264/500, Total Reward: 1313.9746284484863
# Episode 265/500, Total Reward: -9995.95696258545
# Episode 266/500, Total Reward: -9842.799541473389
# Episode 267/500, Total Reward: -9991.448669433594
# Episode 268/500, Total Reward: -9898.466678619385
# Episode 269/500, Total Reward: -9846.773513793945
# Episode 270/500, Total Reward: -9979.22569656372
# Episode 271/500, Total Reward: -9862.733825683594
# Episode 272/500, Total Reward: -9905.839237213135
# Episode 273/500, Total Reward: -9916.21477508545
# Episode 274/500, Total Reward: -9881.232803344727
# Episode 275/500, Total Reward: -9976.476127624512
# Episode 276/500, Total Reward: -9938.275409698486
# Episode 277/500, Total Reward: -9935.921741485596
# Episode 278/500, Total Reward: -9740.095066070557
# Episode 279/500, Total Reward: -9783.826877593994
# Episode 280/500, Total Reward: -9996.387176513672
# Episode 281/500, Total Reward: -9860.03651046753
# Episode 282/500, Total Reward: -9953.886878967285
# Episode 283/500, Total Reward: -9984.509284973145
# Episode 284/500, Total Reward: -9859.58657836914
# Episode 285/500, Total Reward: -9997.508472442627
# Episode 286/500, Total Reward: -9799.265949249268
# Episode 287/500, Total Reward: -9875.530265808105
# Episode 288/500, Total Reward: -9885.66790008545
# Episode 289/500, Total Reward: 6618.778030395508
# Episode 290/500, Total Reward: -9809.652111053467
# Episode 291/500, Total Reward: -9840.333099365234
# Episode 292/500, Total Reward: -9816.01791381836
# Episode 293/500, Total Reward: -9970.276374816895
# Episode 294/500, Total Reward: -9985.273792266846
# Episode 295/500, Total Reward: -9991.552333831787
# Episode 296/500, Total Reward: -9977.715320587158
# Episode 297/500, Total Reward: -9998.716911315918
# Episode 298/500, Total Reward: -9815.61351776123
# Episode 299/500, Total Reward: -9886.129898071289
# Episode 300/500, Total Reward: -9874.015617370605
# Episode 301/500, Total Reward: -9923.742485046387
# Episode 302/500, Total Reward: -9940.265209197998
# Episode 303/500, Total Reward: -9965.236740112305
# Episode 304/500, Total Reward: -9843.483982086182
# Episode 305/500, Total Reward: -9805.935386657715
# Episode 306/500, Total Reward: -9998.972328186035
# Episode 307/500, Total Reward: -9842.0234375
# Episode 308/500, Total Reward: -9918.097469329834
# Episode 309/500, Total Reward: -9999.02043914795
# Episode 310/500, Total Reward: -9923.459522247314
# Episode 311/500, Total Reward: -9880.300994873047
# Episode 312/500, Total Reward: -9928.063186645508
# Episode 313/500, Total Reward: 7716.011009216309
# Episode 314/500, Total Reward: 13102.318702697754
# Episode 315/500, Total Reward: -9841.344818115234
# Episode 316/500, Total Reward: -9878.842971801758
# Episode 317/500, Total Reward: 13106.452499389648
# Episode 318/500, Total Reward: 15205.853256225586
# Episode 319/500, Total Reward: -9816.368755340576
# Episode 320/500, Total Reward: 18115.199951171875
# Episode 321/500, Total Reward: 20933.362045288086
# Episode 322/500, Total Reward: 4854.826663970947
# Episode 323/500, Total Reward: -9777.952060699463
# Episode 324/500, Total Reward: -9757.36520767212
# Episode 325/500, Total Reward: 5565.097320556641
# Episode 326/500, Total Reward: -9813.183193206787
# Episode 327/500, Total Reward: -9997.841869354248
# Episode 328/500, Total Reward: -9863.361988067627
# Episode 329/500, Total Reward: -9981.289234161377
# Episode 330/500, Total Reward: -9973.408977508545
# Episode 331/500, Total Reward: -9922.396881103516
# Episode 332/500, Total Reward: -9841.377975463867
# Episode 333/500, Total Reward: -9998.317443847656
# Episode 334/500, Total Reward: -9987.557582855225
# Episode 335/500, Total Reward: -1124.1473274230957
# Episode 336/500, Total Reward: -897.8674163818359
# Episode 337/500, Total Reward: 11667.644073486328
# Episode 338/500, Total Reward: 16530.988006591797
# Episode 339/500, Total Reward: 14703.715309143066
# Episode 340/500, Total Reward: -9815.21265411377
# Episode 341/500, Total Reward: -9822.069751739502
# Episode 342/500, Total Reward: -9851.787101745605
# Episode 343/500, Total Reward: 8821.538440704346
# Episode 344/500, Total Reward: 5195.695999145508
# Episode 345/500, Total Reward: -9839.455558776855
# Episode 346/500, Total Reward: 10141.755470275879
# Episode 347/500, Total Reward: -9788.610191345215
# Episode 348/500, Total Reward: -9857.3791847229
# Episode 349/500, Total Reward: 5529.510368347168
# Episode 350/500, Total Reward: -9831.543083190918
# Episode 351/500, Total Reward: 282.73741149902344
# Episode 352/500, Total Reward: -324.7843933105469
# Episode 353/500, Total Reward: 3253.624397277832
# Episode 354/500, Total Reward: -487.0323944091797
# Episode 355/500, Total Reward: 359.3508758544922
# Episode 356/500, Total Reward: -9859.926040649414
# Episode 357/500, Total Reward: -9875.438667297363
# Episode 358/500, Total Reward: 1551.5166549682617
# Episode 359/500, Total Reward: 4433.149482727051
# Episode 360/500, Total Reward: -1216.3168106079102
# Episode 361/500, Total Reward: 2978.322971343994
# Episode 362/500, Total Reward: 1280.4674682617188
# Episode 363/500, Total Reward: -1383.370246887207
# Episode 364/500, Total Reward: 608.4733276367188
# Episode 365/500, Total Reward: 554.5806045532227
# Episode 366/500, Total Reward: 1597.6624946594238
# Episode 367/500, Total Reward: 2116.1212882995605
# Episode 368/500, Total Reward: 2096.1060333251953
# Episode 369/500, Total Reward: -715.3313102722168
# Episode 370/500, Total Reward: 3304.368885040283
# Episode 371/500, Total Reward: 2412.2660522460938
# Episode 372/500, Total Reward: 704.6784362792969
# Episode 373/500, Total Reward: -3030.4658851623535
# Episode 374/500, Total Reward: 2147.4938888549805
# Episode 375/500, Total Reward: 815.0309371948242
# Episode 376/500, Total Reward: 1391.5271835327148
# Episode 377/500, Total Reward: 3983.820426940918
# Episode 378/500, Total Reward: 1705.5902214050293
# Episode 379/500, Total Reward: 850.3139190673828
# Episode 380/500, Total Reward: -1384.1640663146973
# Episode 381/500, Total Reward: 1374.3459167480469
# Episode 382/500, Total Reward: 346.2794189453125
# Episode 383/500, Total Reward: 479.3376770019531
# Episode 384/500, Total Reward: 2469.373836517334
# Episode 385/500, Total Reward: -912.6798896789551
# Episode 386/500, Total Reward: -9916.069145202637
# Episode 387/500, Total Reward: -9791.746105194092
# Episode 388/500, Total Reward: -9852.299125671387
# Episode 389/500, Total Reward: 714.4340591430664
# Episode 390/500, Total Reward: -9887.354370117188
# Episode 391/500, Total Reward: -9831.478118896484
# Episode 392/500, Total Reward: -9827.92017364502
# Episode 393/500, Total Reward: -9805.267837524414
# Episode 394/500, Total Reward: 139.10015106201172
# Episode 395/500, Total Reward: -9845.57122039795
# Episode 396/500, Total Reward: 19389.41960144043
# Episode 397/500, Total Reward: 5695.540985107422
# Episode 398/500, Total Reward: 4778.823532104492
# Episode 399/500, Total Reward: -9957.753875732422
# Episode 400/500, Total Reward: -9852.687774658203
# Episode 401/500, Total Reward: 12659.730266571045
# Episode 402/500, Total Reward: -281.2072982788086
# Episode 403/500, Total Reward: -9754.844329833984
# Episode 404/500, Total Reward: 22024.178855895996
# Episode 405/500, Total Reward: 10097.99451828003
# Episode 406/500, Total Reward: -9982.114868164062
# Episode 407/500, Total Reward: -9990.252258300781
# Episode 408/500, Total Reward: -9848.267120361328
# Episode 409/500, Total Reward: -9944.223587036133
# Episode 410/500, Total Reward: -9841.624004364014
# Episode 411/500, Total Reward: -9924.840553283691
# Episode 412/500, Total Reward: -9816.335151672363
# Episode 413/500, Total Reward: 5270.291976928711
# Episode 414/500, Total Reward: -9818.967575073242
# Episode 415/500, Total Reward: -9937.117378234863
# Episode 416/500, Total Reward: -9947.770568847656
# Episode 417/500, Total Reward: -9989.607063293457
# Episode 418/500, Total Reward: -9823.033279418945
# Episode 419/500, Total Reward: -9804.242164611816
# Episode 420/500, Total Reward: -9775.554958343506
# Episode 421/500, Total Reward: 17654.06932067871
# Episode 422/500, Total Reward: 2741.656753540039
# Episode 423/500, Total Reward: -9929.53744506836
# Episode 424/500, Total Reward: -9775.373802185059
# Episode 425/500, Total Reward: 9989.314308166504
# Episode 426/500, Total Reward: 5728.450458526611
# Episode 427/500, Total Reward: -9809.780311584473
# Episode 428/500, Total Reward: -9816.245582580566
# Episode 429/500, Total Reward: -9816.740020751953
# Episode 430/500, Total Reward: 1136.7293701171875
# Episode 431/500, Total Reward: -9947.542198181152
# Episode 432/500, Total Reward: -1119.8954963684082
# Episode 433/500, Total Reward: -9971.202194213867
# Episode 434/500, Total Reward: 7306.637664794922
# Episode 435/500, Total Reward: 952.3634643554688
# Episode 436/500, Total Reward: 14380.733192443848
# Episode 437/500, Total Reward: 2566.0209045410156
# Episode 438/500, Total Reward: 15916.358573913574
# Episode 439/500, Total Reward: -9938.378925323486
# Episode 440/500, Total Reward: -196.48017120361328
# Episode 441/500, Total Reward: 2616.456382751465
# Episode 442/500, Total Reward: -9790.4546585083
# Episode 443/500, Total Reward: 9289.999759674072
# Episode 444/500, Total Reward: 2746.8178634643555
# Episode 445/500, Total Reward: -9915.974647521973
# Episode 446/500, Total Reward: 3370.784408569336
# Episode 447/500, Total Reward: -9998.898338317871
# Episode 448/500, Total Reward: 6927.945823669434
# Episode 449/500, Total Reward: -9908.11457824707
# Episode 450/500, Total Reward: -9860.083351135254
# Episode 451/500, Total Reward: 1072.398536682129
# Episode 452/500, Total Reward: -9979.60334777832
# Episode 453/500, Total Reward: -9999.716804504395
# Episode 454/500, Total Reward: 8022.629745483398
# Episode 455/500, Total Reward: -9829.845542907715
# Episode 456/500, Total Reward: -9848.839332580566
# Episode 457/500, Total Reward: -9908.896965026855
# Episode 458/500, Total Reward: -9985.199569702148
# Episode 459/500, Total Reward: -9986.008155822754
# Episode 460/500, Total Reward: -9778.113876342773
# Episode 461/500, Total Reward: -9815.199493408203
# Episode 462/500, Total Reward: -9834.70905303955
# Episode 463/500, Total Reward: -9855.472862243652
# Episode 464/500, Total Reward: -9792.929862976074
# Episode 465/500, Total Reward: -9923.812515258789
# Episode 466/500, Total Reward: -9885.7685546875
# Episode 467/500, Total Reward: -9934.675155639648
# Episode 468/500, Total Reward: -9850.941284179688
# Episode 469/500, Total Reward: -9812.725852966309
# Episode 470/500, Total Reward: 18418.717681884766
# Episode 471/500, Total Reward: -9886.59033203125
# Episode 472/500, Total Reward: -9975.486045837402
# Episode 473/500, Total Reward: -9903.010971069336
# Episode 474/500, Total Reward: -9914.369850158691
# Episode 475/500, Total Reward: -9811.280258178711
# Episode 476/500, Total Reward: -9945.792701721191
# Episode 477/500, Total Reward: -9800.940223693848
# Episode 478/500, Total Reward: -9993.532928466797
# Episode 479/500, Total Reward: -9943.018466949463
# Episode 480/500, Total Reward: -9909.542297363281
# Episode 481/500, Total Reward: -9953.281730651855
# Episode 482/500, Total Reward: -9855.491432189941
# Episode 483/500, Total Reward: -9974.3955078125
# Episode 484/500, Total Reward: -9970.425918579102
# Episode 485/500, Total Reward: 7493.700332641602
# Episode 486/500, Total Reward: 9280.56169128418
# Episode 487/500, Total Reward: 9352.689666748047
# Episode 488/500, Total Reward: -9812.694808959961
# Episode 489/500, Total Reward: -9959.439758300781
# Episode 490/500, Total Reward: -9978.550270080566
# Episode 491/500, Total Reward: -9978.649742126465
# Episode 492/500, Total Reward: -9948.273559570312
# Episode 493/500, Total Reward: -9998.590545654297
# Episode 494/500, Total Reward: -9820.32498550415
# Episode 495/500, Total Reward: -9778.569519042969
# Episode 496/500, Total Reward: -9765.625183105469
# Episode 497/500, Total Reward: -9780.985527038574
# Episode 498/500, Total Reward: -9982.26107788086
# Episode 499/500, Total Reward: 440.5066604614258
# Episode 500/500, Total Reward: -302.7665557861328
# Training Complete!

# %% [markdown]
# Here, we trained the AI Trading Agent using Deep Q-Learning, simulating 500 trading sessions where the agent learned from experience. It leveraged Exploration & Exploitation, initially taking random actions before making more informed decisions as training progressed.

# %% [markdown]
# Experience Replay is used to store past experiences, allowing the neural network to learn through batch training. Throughout the process, we tracked rewards to measure the agent’s performance improvements over time.
#
# After training, we can test the agent on new market data by allowing it to make decisions without random exploration:

# %%
# create a fresh environment instance for testing
test_env = TradingEnvironment(data)
state = test_env.reset()
done = False

# simulate a trading session using the trained agent
while not done:
    # always choose the best action (exploitation)
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance
profit = final_balance - test_env.initial_balance
print(f"Final Balance after testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# <ipython-input-5-3915787d8dfc>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# <ipython-input-5-3915787d8dfc>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# <ipython-input-5-3915787d8dfc>:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# <ipython-input-5-3915787d8dfc>:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# <ipython-input-6-71f231bc395a>:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Final Balance after testing: $11113.19
# Total Profit: $1113.19

# %% [markdown]
# The agent started with 10,000 and ended with 11,113.19. Profit = 1113.19, meaning the agent made a decentl and positive return.

# %% [markdown]
# Summary
#
# We explored how to build an AI trading agent using Agentic AI and Deep Q-Learning, enabling it to make autonomous trading decisions. After training, our AI agent successfully generated a small but positive profit, which demonstrates its ability to navigate market fluctuations.
