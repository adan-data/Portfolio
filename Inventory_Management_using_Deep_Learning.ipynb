# %% [markdown]
# Upload data

# %%
# !wget -N "https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/data_week1.zip"
# !unzip -qo data_week1.zip
# !rm data_week1.zip
# Out:
# --2024-05-04 21:31:56--  https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/data_week1.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.158.123, 52.219.158.83, 52.219.160.71, ...
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.158.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101230622 (97M) [application/x-zip-compressed]
# Saving to: ‘data_week1.zip’
#
# data_week1.zip      100%[===================>]  96.54M  13.3MB/s    in 8.9s
#
# 2024-05-04 21:32:06 (10.8 MB/s) - ‘data_week1.zip’ saved [101230622/101230622]

# %% [markdown]
# Import libraries

# %%
# !pip install imgaug
# Out:
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug) (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.0.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (3.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (2024.4.24)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (2.8.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, random, cv2, pickle, json, itertools
import imgaug.augmenters as iaa
import imgaug.imgaug
import tensorflow as tf

from IPython.display import SVG
from tensorflow.keras.utils import plot_model, model_to_dot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.utils import class_weight
from tqdm import tqdm
from sklearn.preprocessing import LabelBinarizer

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Add, Input, Conv2D, Dropout, Activation, BatchNormalization, MaxPool2D, ZeroPadding2D, AveragePooling2D, Flatten, Dense)
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import *

# %% [markdown]
# Function to plot model metrics

# %%
def show_final_history(history):

    plt.style.use("ggplot")
    fig, ax = plt.subplots(1,2,figsize=(15,5))
    ax[0].set_title('Loss')
    ax[1].set_title('Accuracy')
    ax[0].plot(history.history['loss'],label='Train Loss')
    ax[0].plot(history.history['val_loss'],label='Validation Loss')
    ax[1].plot(history.history['accuracy'],label='Train Accuracy')
    ax[1].plot(history.history['val_accuracy'],label='Validation Accuracy')

    ax[0].legend(loc='upper right')
    ax[1].legend(loc='lower right')
    plt.show();
    pass

# %% [markdown]
# Create classes based off dataset

# %%
datasets = ['data_week1/images']

class_names = ["MILK","NUTS","OIL","SODA","TEA"]

class_name_labels = {class_name:i for i,class_name in enumerate(class_names)}

num_classes = len(class_names)
class_name_labels
# Out:
# {'MILK': 0, 'NUTS': 1, 'OIL': 2, 'SODA': 3, 'TEA': 4}

# %% [markdown]
# Load data

# %%
def load_data():
    images, labels = [], []

    for dataset in datasets:

        for folder in os.listdir(dataset):
            label = class_name_labels[folder]

            for file in tqdm(os.listdir(os.path.join(dataset,folder))):

                img_path = os.path.join(dataset,folder,file)

                img = cv2.imread(img_path)
                img = cv2.resize(img, (96,96))

                images.append(img)
                labels.append(label)
                pass
            pass

        images = np.array(images,dtype=np.float32)/255.0
        labels = np.array(labels,dtype=np.float32)
        pass

    return (images, labels)
    pass

# %%
(images, labels) = load_data()
images.shape, labels.shape
# Out:
# 100%|██████████| 162/162 [00:00<00:00, 178.23it/s]
# 100%|██████████| 168/168 [00:00<00:00, 299.18it/s]
# 100%|██████████| 177/177 [00:00<00:00, 258.50it/s]
# 100%|██████████| 143/143 [00:00<00:00, 266.50it/s]
# 100%|██████████| 283/283 [00:01<00:00, 258.46it/s]
# ((933, 96, 96, 3), (933,))

# %% [markdown]
# Check classes

# %%
n_labels = labels.shape[0]

_, count = np.unique(labels, return_counts=True)

df = pd.DataFrame(data = count)
df['Class Label'] = class_names
df.columns = ['Count','Class-Label']
df.set_index('Class-Label',inplace=True)
df
# Out:
#              Count
# Class-Label
# MILK           162
# NUTS           168
# OIL            143
# SODA           177
# TEA            283

# %% [markdown]
# Augmenting images to prevent underfitting and remove bias in dataset

# %%
def augment_add(images, seq, labels):

    augmented_images, augmented_labels = [],[]
    for idx,img in tqdm(enumerate(images)):

        if labels[idx] == 1:
            image_aug_1 = seq.augment_image(image=img)
            image_aug_2 = seq.augment_image(image=img)
            augmented_images.append(image_aug_1)
            augmented_images.append(image_aug_2)
            augmented_labels.append(labels[idx])
            augmented_labels.append(labels[idx])
        pass

    augmented_images = np.array(augmented_images, dtype=np.float32)
    augmented_labels = np.array(augmented_labels, dtype=np.float32)

    return (augmented_images, augmented_labels)
    pass

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0,0.1)),
    iaa.LinearContrast((0.75,1.5)),
    iaa.Multiply((0.8,1.2), per_channel=0.2),
    iaa.Affine(
        scale={'x':(0.8,1.2), "y":(0.8,1.2)},
        translate_percent={"x":(-0.2,0.2),"y":(-0.2,0.2)},
        rotate=(-25,25),
        shear=(-8,8)
    )
], random_order=True)

# %%
(aug_images, aug_labels) = augment_add(images, seq, labels)
images = np.concatenate([images, aug_images])
labels = np.concatenate([labels, aug_labels])
# Out:
# 933it [00:02, 367.38it/s]

# %%
images.shape, labels.shape
# Out:
# ((1269, 96, 96, 3), (1269,))

# %%
labels = to_categorical(labels)

# %% [markdown]
# Dividing images into train, validation, and test sets

# %%
np.random.seed(42)
np.random.shuffle(images)

np.random.seed(42)
np.random.shuffle(labels)

# %%
total_count = len(images)
total_count

train = int(0.7*total_count)
val = int(0.2*total_count)
test = int(0.1*total_count)

train_images, train_labels = images[:train], labels[:train]
val_images, val_labels = images[train:(val+train)], labels[train:(val+train)]
test_images, test_labels = images[-test:], labels[-test:]

train_images.shape, val_images.shape, test_images.shape
# Out:
# ((888, 96, 96, 3), (253, 96, 96, 3), (126, 96, 96, 3))

# %% [markdown]
# Defining model architecture

# %%
model = Sequential([
    Input(shape=(96,96,3)),
    ZeroPadding2D((5,5)),
    Conv2D(32, 3, activation='relu'),
    BatchNormalization(),
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(32, 3, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(32, 3, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.4),
    Conv2D(32, 3, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(32, 3, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Dropout(0.3),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(5, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d (ZeroPaddin  (None, 106, 106, 3)       0
#  g2D)
#
#  conv2d (Conv2D)             (None, 104, 104, 32)      896
#
#  batch_normalization (Batch  (None, 104, 104, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 52, 52, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 52, 52, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 25, 25, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 11, 11, 32)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 11, 11, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 9, 9, 32)          9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 4, 4, 32)          0
#
#  conv2d_4 (Conv2D)           (None, 2, 2, 32)          9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 32)          0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 32)          0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 40453 (158.02 KB)
# Trainable params: 40389 (157.77 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Defining model callbacks and compiling the model with the Adam optimizer

# %%
checkpoint = ModelCheckpoint(
    './base.model',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max',
    save_weights_only=False,
    save_frequency=1
)
earlystop = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=50,
    verbose=1,
    mode='auto'
)

opt = Adam(lr=1e-3)

callbacks = [checkpoint,earlystop]

model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
epochs = 200
batch_size = 32

history = model.fit(train_images,train_labels,
                    batch_size=batch_size,
                   steps_per_epoch=len(train_images)//batch_size,
                   epochs=epochs,
                   verbose=1,
                   validation_data=(val_images,val_labels),
                   validation_steps=len(val_images)//batch_size,
                   callbacks=callbacks
                   )
# Out:
# Epoch 1/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5910 - accuracy: 0.2824
# Epoch 1: val_accuracy improved from -inf to 0.41964, saving model to ./base.model
# 27/27 [==============================] - 26s 845ms/step - loss: 0.5910 - accuracy: 0.2824 - val_loss: 0.6640 - val_accuracy: 0.4196
# Epoch 2/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5209 - accuracy: 0.3294
# Epoch 2: val_accuracy did not improve from 0.41964
# 27/27 [==============================] - 20s 759ms/step - loss: 0.5209 - accuracy: 0.3294 - val_loss: 0.6498 - val_accuracy: 0.4196
# Epoch 3/200
# 27/27 [==============================] - ETA: 0s - loss: 0.5056 - accuracy: 0.3446
# Epoch 3: val_accuracy did not improve from 0.41964
# 27/27 [==============================] - 19s 711ms/step - loss: 0.5056 - accuracy: 0.3446 - val_loss: 0.6358 - val_accuracy: 0.4196
# Epoch 4/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.3820
# Epoch 4: val_accuracy did not improve from 0.41964
# 27/27 [==============================] - 20s 738ms/step - loss: 0.4900 - accuracy: 0.3820 - val_loss: 0.6217 - val_accuracy: 0.4196
# Epoch 5/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4892 - accuracy: 0.3715
# Epoch 5: val_accuracy did not improve from 0.41964
# 27/27 [==============================] - 19s 700ms/step - loss: 0.4892 - accuracy: 0.3715 - val_loss: 0.6155 - val_accuracy: 0.4196
# Epoch 6/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.3773
# Epoch 6: val_accuracy did not improve from 0.41964
# 27/27 [==============================] - 20s 747ms/step - loss: 0.4806 - accuracy: 0.3773 - val_loss: 0.5981 - val_accuracy: 0.4196
# Epoch 7/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.3972
# Epoch 7: val_accuracy did not improve from 0.41964
# 27/27 [==============================] - 19s 717ms/step - loss: 0.4705 - accuracy: 0.3972 - val_loss: 0.5866 - val_accuracy: 0.4196
# Epoch 8/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.3972
# Epoch 8: val_accuracy improved from 0.41964 to 0.43750, saving model to ./base.model
# 27/27 [==============================] - 22s 838ms/step - loss: 0.4681 - accuracy: 0.3972 - val_loss: 0.5703 - val_accuracy: 0.4375
# Epoch 9/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4580 - accuracy: 0.3820
# Epoch 9: val_accuracy improved from 0.43750 to 0.44643, saving model to ./base.model
# 27/27 [==============================] - 29s 1s/step - loss: 0.4580 - accuracy: 0.3820 - val_loss: 0.5756 - val_accuracy: 0.4464
# Epoch 10/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.3797
# Epoch 10: val_accuracy improved from 0.44643 to 0.46429, saving model to ./base.model
# 27/27 [==============================] - 23s 862ms/step - loss: 0.4526 - accuracy: 0.3797 - val_loss: 0.5533 - val_accuracy: 0.4643
# Epoch 11/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.4264
# Epoch 11: val_accuracy improved from 0.46429 to 0.48214, saving model to ./base.model
# 27/27 [==============================] - 22s 811ms/step - loss: 0.4324 - accuracy: 0.4264 - val_loss: 0.5368 - val_accuracy: 0.4821
# Epoch 12/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.4276
# Epoch 12: val_accuracy improved from 0.48214 to 0.53571, saving model to ./base.model
# 27/27 [==============================] - 23s 864ms/step - loss: 0.4195 - accuracy: 0.4276 - val_loss: 0.5236 - val_accuracy: 0.5357
# Epoch 13/200
# 27/27 [==============================] - ETA: 0s - loss: 0.4147 - accuracy: 0.4486
# Epoch 13: val_accuracy did not improve from 0.53571
# 27/27 [==============================] - 20s 751ms/step - loss: 0.4147 - accuracy: 0.4486 - val_loss: 0.5022 - val_accuracy: 0.5134
# Epoch 14/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3956 - accuracy: 0.4942
# Epoch 14: val_accuracy did not improve from 0.53571
# 27/27 [==============================] - 19s 712ms/step - loss: 0.3956 - accuracy: 0.4942 - val_loss: 0.4884 - val_accuracy: 0.4821
# Epoch 15/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3886 - accuracy: 0.4883
# Epoch 15: val_accuracy improved from 0.53571 to 0.57589, saving model to ./base.model
# 27/27 [==============================] - 24s 886ms/step - loss: 0.3886 - accuracy: 0.4883 - val_loss: 0.4611 - val_accuracy: 0.5759
# Epoch 16/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3838 - accuracy: 0.5035
# Epoch 16: val_accuracy did not improve from 0.57589
# 27/27 [==============================] - 19s 715ms/step - loss: 0.3838 - accuracy: 0.5035 - val_loss: 0.4538 - val_accuracy: 0.5134
# Epoch 17/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3926 - accuracy: 0.4755
# Epoch 17: val_accuracy did not improve from 0.57589
# 27/27 [==============================] - 20s 739ms/step - loss: 0.3926 - accuracy: 0.4755 - val_loss: 0.4607 - val_accuracy: 0.4911
# Epoch 18/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.5222
# Epoch 18: val_accuracy did not improve from 0.57589
# 27/27 [==============================] - 19s 692ms/step - loss: 0.3766 - accuracy: 0.5222 - val_loss: 0.4303 - val_accuracy: 0.5536
# Epoch 19/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3595 - accuracy: 0.5327
# Epoch 19: val_accuracy improved from 0.57589 to 0.58036, saving model to ./base.model
# 27/27 [==============================] - 23s 851ms/step - loss: 0.3595 - accuracy: 0.5327 - val_loss: 0.4047 - val_accuracy: 0.5804
# Epoch 20/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.5643
# Epoch 20: val_accuracy did not improve from 0.58036
# 27/27 [==============================] - 19s 713ms/step - loss: 0.3430 - accuracy: 0.5643 - val_loss: 0.3747 - val_accuracy: 0.5804
# Epoch 21/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.5619
# Epoch 21: val_accuracy did not improve from 0.58036
# 27/27 [==============================] - 20s 739ms/step - loss: 0.3491 - accuracy: 0.5619 - val_loss: 0.3942 - val_accuracy: 0.5491
# Epoch 22/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.5631
# Epoch 22: val_accuracy did not improve from 0.58036
# 27/27 [==============================] - 19s 718ms/step - loss: 0.3477 - accuracy: 0.5631 - val_loss: 0.3685 - val_accuracy: 0.5670
# Epoch 23/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.5502
# Epoch 23: val_accuracy did not improve from 0.58036
# 27/27 [==============================] - 29s 1s/step - loss: 0.3491 - accuracy: 0.5502 - val_loss: 0.3709 - val_accuracy: 0.5402
# Epoch 24/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.5923
# Epoch 24: val_accuracy improved from 0.58036 to 0.60714, saving model to ./base.model
# 27/27 [==============================] - 29s 1s/step - loss: 0.3303 - accuracy: 0.5923 - val_loss: 0.3431 - val_accuracy: 0.6071
# Epoch 25/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3283 - accuracy: 0.5981
# Epoch 25: val_accuracy improved from 0.60714 to 0.61161, saving model to ./base.model
# 27/27 [==============================] - 37s 1s/step - loss: 0.3283 - accuracy: 0.5981 - val_loss: 0.3483 - val_accuracy: 0.6116
# Epoch 26/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.5794
# Epoch 26: val_accuracy did not improve from 0.61161
# 27/27 [==============================] - 23s 830ms/step - loss: 0.3488 - accuracy: 0.5794 - val_loss: 0.3426 - val_accuracy: 0.5893
# Epoch 27/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.5946
# Epoch 27: val_accuracy did not improve from 0.61161
# 27/27 [==============================] - 21s 765ms/step - loss: 0.3264 - accuracy: 0.5946 - val_loss: 0.3484 - val_accuracy: 0.5938
# Epoch 28/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.6005
# Epoch 28: val_accuracy did not improve from 0.61161
# 27/27 [==============================] - 19s 708ms/step - loss: 0.3330 - accuracy: 0.6005 - val_loss: 0.3645 - val_accuracy: 0.5759
# Epoch 29/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.5914
# Epoch 29: val_accuracy improved from 0.61161 to 0.64286, saving model to ./base.model
# 27/27 [==============================] - 25s 923ms/step - loss: 0.3221 - accuracy: 0.5914 - val_loss: 0.3189 - val_accuracy: 0.6429
# Epoch 30/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.6250
# Epoch 30: val_accuracy did not improve from 0.64286
# 27/27 [==============================] - 24s 897ms/step - loss: 0.3097 - accuracy: 0.6250 - val_loss: 0.3239 - val_accuracy: 0.6205
# Epoch 31/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.6320
# Epoch 31: val_accuracy did not improve from 0.64286
# 27/27 [==============================] - 19s 715ms/step - loss: 0.3033 - accuracy: 0.6320 - val_loss: 0.3109 - val_accuracy: 0.6339
# Epoch 32/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.6530
# Epoch 32: val_accuracy did not improve from 0.64286
# 27/27 [==============================] - 21s 757ms/step - loss: 0.3060 - accuracy: 0.6530 - val_loss: 0.3236 - val_accuracy: 0.6205
# Epoch 33/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2908 - accuracy: 0.6565
# Epoch 33: val_accuracy did not improve from 0.64286
# 27/27 [==============================] - 19s 722ms/step - loss: 0.2908 - accuracy: 0.6565 - val_loss: 0.3071 - val_accuracy: 0.6027
# Epoch 34/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.6238
# Epoch 34: val_accuracy did not improve from 0.64286
# 27/27 [==============================] - 22s 800ms/step - loss: 0.3122 - accuracy: 0.6238 - val_loss: 0.3302 - val_accuracy: 0.5893
# Epoch 35/200
# 27/27 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.6332
# Epoch 35: val_accuracy improved from 0.64286 to 0.64732, saving model to ./base.model
# 27/27 [==============================] - 24s 898ms/step - loss: 0.3000 - accuracy: 0.6332 - val_loss: 0.2910 - val_accuracy: 0.6473
# Epoch 36/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.6437
# Epoch 36: val_accuracy did not improve from 0.64732
# 27/27 [==============================] - 29s 1s/step - loss: 0.2924 - accuracy: 0.6437 - val_loss: 0.2855 - val_accuracy: 0.6295
# Epoch 37/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.6437
# Epoch 37: val_accuracy did not improve from 0.64732
# 27/27 [==============================] - 19s 721ms/step - loss: 0.2960 - accuracy: 0.6437 - val_loss: 0.2830 - val_accuracy: 0.6473
# Epoch 38/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2845 - accuracy: 0.6764
# Epoch 38: val_accuracy improved from 0.64732 to 0.65625, saving model to ./base.model
# 27/27 [==============================] - 23s 861ms/step - loss: 0.2845 - accuracy: 0.6764 - val_loss: 0.2689 - val_accuracy: 0.6562
# Epoch 39/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.6717
# Epoch 39: val_accuracy did not improve from 0.65625
# 27/27 [==============================] - 19s 717ms/step - loss: 0.2860 - accuracy: 0.6717 - val_loss: 0.2952 - val_accuracy: 0.6250
# Epoch 40/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.6671
# Epoch 40: val_accuracy improved from 0.65625 to 0.66518, saving model to ./base.model
# 27/27 [==============================] - 24s 874ms/step - loss: 0.2819 - accuracy: 0.6671 - val_loss: 0.2749 - val_accuracy: 0.6652
# Epoch 41/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2651 - accuracy: 0.6881
# Epoch 41: val_accuracy did not improve from 0.66518
# 27/27 [==============================] - 21s 771ms/step - loss: 0.2651 - accuracy: 0.6881 - val_loss: 0.2894 - val_accuracy: 0.6116
# Epoch 42/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2782 - accuracy: 0.6741
# Epoch 42: val_accuracy improved from 0.66518 to 0.66964, saving model to ./base.model
# 27/27 [==============================] - 22s 814ms/step - loss: 0.2782 - accuracy: 0.6741 - val_loss: 0.2816 - val_accuracy: 0.6696
# Epoch 43/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2628 - accuracy: 0.7044
# Epoch 43: val_accuracy did not improve from 0.66964
# 27/27 [==============================] - 21s 766ms/step - loss: 0.2628 - accuracy: 0.7044 - val_loss: 0.2820 - val_accuracy: 0.6607
# Epoch 44/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.6893
# Epoch 44: val_accuracy did not improve from 0.66964
# 27/27 [==============================] - 19s 721ms/step - loss: 0.2657 - accuracy: 0.6893 - val_loss: 0.2722 - val_accuracy: 0.6384
# Epoch 45/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.6916
# Epoch 45: val_accuracy improved from 0.66964 to 0.74107, saving model to ./base.model
# 27/27 [==============================] - 23s 857ms/step - loss: 0.2634 - accuracy: 0.6916 - val_loss: 0.2641 - val_accuracy: 0.7411
# Epoch 46/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2369 - accuracy: 0.7173
# Epoch 46: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 21s 767ms/step - loss: 0.2369 - accuracy: 0.7173 - val_loss: 0.2640 - val_accuracy: 0.6786
# Epoch 47/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.7138
# Epoch 47: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 20s 732ms/step - loss: 0.2516 - accuracy: 0.7138 - val_loss: 0.2644 - val_accuracy: 0.6518
# Epoch 48/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.6916
# Epoch 48: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 21s 767ms/step - loss: 0.2723 - accuracy: 0.6916 - val_loss: 0.2808 - val_accuracy: 0.6518
# Epoch 49/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2573 - accuracy: 0.7009
# Epoch 49: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 20s 734ms/step - loss: 0.2573 - accuracy: 0.7009 - val_loss: 0.2648 - val_accuracy: 0.6652
# Epoch 50/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.7325
# Epoch 50: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 22s 803ms/step - loss: 0.2402 - accuracy: 0.7325 - val_loss: 0.2946 - val_accuracy: 0.6652
# Epoch 51/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.7150
# Epoch 51: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 19s 725ms/step - loss: 0.2602 - accuracy: 0.7150 - val_loss: 0.2577 - val_accuracy: 0.6875
# Epoch 52/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.7465
# Epoch 52: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 21s 773ms/step - loss: 0.2250 - accuracy: 0.7465 - val_loss: 0.2528 - val_accuracy: 0.7054
# Epoch 53/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.7255
# Epoch 53: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 19s 724ms/step - loss: 0.2426 - accuracy: 0.7255 - val_loss: 0.2475 - val_accuracy: 0.7098
# Epoch 54/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2419 - accuracy: 0.7290
# Epoch 54: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 21s 770ms/step - loss: 0.2419 - accuracy: 0.7290 - val_loss: 0.2493 - val_accuracy: 0.7321
# Epoch 55/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2145 - accuracy: 0.7523
# Epoch 55: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 19s 705ms/step - loss: 0.2145 - accuracy: 0.7523 - val_loss: 0.2597 - val_accuracy: 0.7054
# Epoch 56/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.7605
# Epoch 56: val_accuracy did not improve from 0.74107
# 27/27 [==============================] - 21s 773ms/step - loss: 0.2316 - accuracy: 0.7605 - val_loss: 0.2667 - val_accuracy: 0.6964
# Epoch 57/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.7407
# Epoch 57: val_accuracy improved from 0.74107 to 0.77679, saving model to ./base.model
# 27/27 [==============================] - 23s 855ms/step - loss: 0.2476 - accuracy: 0.7407 - val_loss: 0.2252 - val_accuracy: 0.7768
# Epoch 58/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.7477
# Epoch 58: val_accuracy did not improve from 0.77679
# 27/27 [==============================] - 20s 744ms/step - loss: 0.2195 - accuracy: 0.7477 - val_loss: 0.2539 - val_accuracy: 0.7679
# Epoch 59/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2101 - accuracy: 0.7780
# Epoch 59: val_accuracy improved from 0.77679 to 0.79464, saving model to ./base.model
# 27/27 [==============================] - 23s 870ms/step - loss: 0.2101 - accuracy: 0.7780 - val_loss: 0.2104 - val_accuracy: 0.7946
# Epoch 60/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.7722
# Epoch 60: val_accuracy did not improve from 0.79464
# 27/27 [==============================] - 19s 716ms/step - loss: 0.2107 - accuracy: 0.7722 - val_loss: 0.2335 - val_accuracy: 0.7768
# Epoch 61/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.7477
# Epoch 61: val_accuracy did not improve from 0.79464
# 27/27 [==============================] - 21s 772ms/step - loss: 0.2312 - accuracy: 0.7477 - val_loss: 0.2486 - val_accuracy: 0.7366
# Epoch 62/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2099 - accuracy: 0.7582
# Epoch 62: val_accuracy did not improve from 0.79464
# 27/27 [==============================] - 19s 723ms/step - loss: 0.2099 - accuracy: 0.7582 - val_loss: 0.2161 - val_accuracy: 0.7589
# Epoch 63/200
# 27/27 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.7769
# Epoch 63: val_accuracy did not improve from 0.79464
# 27/27 [==============================] - 21s 776ms/step - loss: 0.2074 - accuracy: 0.7769 - val_loss: 0.2026 - val_accuracy: 0.7857
# Epoch 64/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.7991
# Epoch 64: val_accuracy did not improve from 0.79464
# 27/27 [==============================] - 19s 723ms/step - loss: 0.1899 - accuracy: 0.7991 - val_loss: 0.2414 - val_accuracy: 0.7143
# Epoch 65/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.7979
# Epoch 65: val_accuracy did not improve from 0.79464
# 27/27 [==============================] - 27s 1s/step - loss: 0.1963 - accuracy: 0.7979 - val_loss: 0.2484 - val_accuracy: 0.7143
# Epoch 66/200
# 27/27 [==============================] - ETA: 0s - loss: 0.
200
# 27/27 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9054
# Epoch 114: val_accuracy did not improve from 0.86161
# 27/27 [==============================] - 20s 738ms/step - loss: 0.1119 - accuracy: 0.9054 - val_loss: 0.2505 - val_accuracy: 0.7545
# Epoch 115/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.8984
# Epoch 115: val_accuracy did not improve from 0.86161
# 27/27 [==============================] - 21s 773ms/step - loss: 0.1136 - accuracy: 0.8984 - val_loss: 0.1579 - val_accuracy: 0.8304
# Epoch 116/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1489 - accuracy: 0.8633
# Epoch 116: val_accuracy did not improve from 0.86161
# 27/27 [==============================] - 19s 722ms/step - loss: 0.1489 - accuracy: 0.8633 - val_loss: 0.1845 - val_accuracy: 0.8393
# Epoch 117/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9007
# Epoch 117: val_accuracy did not improve from 0.86161
# 27/27 [==============================] - 21s 770ms/step - loss: 0.1167 - accuracy: 0.9007 - val_loss: 0.1702 - val_accuracy: 0.8438
# Epoch 118/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0840 - accuracy: 0.9217
# Epoch 118: val_accuracy did not improve from 0.86161
# 27/27 [==============================] - 20s 728ms/step - loss: 0.0840 - accuracy: 0.9217 - val_loss: 0.1770 - val_accuracy: 0.8036
# Epoch 119/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9042
# Epoch 119: val_accuracy improved from 0.86161 to 0.87054, saving model to ./base.model
# 27/27 [==============================] - 24s 904ms/step - loss: 0.1101 - accuracy: 0.9042 - val_loss: 0.1509 - val_accuracy: 0.8705
# Epoch 120/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9019
# Epoch 120: val_accuracy did not improve from 0.87054
# 27/27 [==============================] - 20s 754ms/step - loss: 0.1160 - accuracy: 0.9019 - val_loss: 0.1696 - val_accuracy: 0.8125
# Epoch 121/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.8797
# Epoch 121: val_accuracy did not improve from 0.87054
# 27/27 [==============================] - 20s 723ms/step - loss: 0.1240 - accuracy: 0.8797 - val_loss: 0.1721 - val_accuracy: 0.8170
# Epoch 122/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9077
# Epoch 122: val_accuracy improved from 0.87054 to 0.88839, saving model to ./base.model
# 27/27 [==============================] - 23s 870ms/step - loss: 0.0948 - accuracy: 0.9077 - val_loss: 0.1383 - val_accuracy: 0.8884
# Epoch 123/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9100
# Epoch 123: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 731ms/step - loss: 0.0989 - accuracy: 0.9100 - val_loss: 0.1575 - val_accuracy: 0.8527
# Epoch 124/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9100
# Epoch 124: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 25s 922ms/step - loss: 0.0965 - accuracy: 0.9100 - val_loss: 0.1642 - val_accuracy: 0.8304
# Epoch 125/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.8949
# Epoch 125: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 26s 945ms/step - loss: 0.1100 - accuracy: 0.8949 - val_loss: 0.1642 - val_accuracy: 0.8482
# Epoch 126/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.8890
# Epoch 126: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 737ms/step - loss: 0.1069 - accuracy: 0.8890 - val_loss: 0.2006 - val_accuracy: 0.8080
# Epoch 127/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.8972
# Epoch 127: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 776ms/step - loss: 0.1094 - accuracy: 0.8972 - val_loss: 0.1649 - val_accuracy: 0.8438
# Epoch 128/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9042
# Epoch 128: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 729ms/step - loss: 0.1081 - accuracy: 0.9042 - val_loss: 0.1831 - val_accuracy: 0.8170
# Epoch 129/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.8890
# Epoch 129: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 759ms/step - loss: 0.1168 - accuracy: 0.8890 - val_loss: 0.1777 - val_accuracy: 0.8214
# Epoch 130/200
# 27/27 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9171
# Epoch 130: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s
200
# 27/27 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9311
# Epoch 187: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 779ms/step - loss: 0.0851 - accuracy: 0.9311 - val_loss: 0.1919 - val_accuracy: 0.8036
# Epoch 188/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9381
# Epoch 188: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 19s 723ms/step - loss: 0.0757 - accuracy: 0.9381 - val_loss: 0.1738 - val_accuracy: 0.8214
# Epoch 189/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9393
# Epoch 189: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 777ms/step - loss: 0.0693 - accuracy: 0.9393 - val_loss: 0.1307 - val_accuracy: 0.8795
# Epoch 190/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9357
# Epoch 190: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 22s 826ms/step - loss: 0.0692 - accuracy: 0.9357 - val_loss: 0.1579 - val_accuracy: 0.8616
# Epoch 191/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9591
# Epoch 191: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 735ms/step - loss: 0.0498 - accuracy: 0.9591 - val_loss: 0.1294 - val_accuracy: 0.8795
# Epoch 192/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9357
# Epoch 192: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 775ms/step - loss: 0.0705 - accuracy: 0.9357 - val_loss: 0.1494 - val_accuracy: 0.8393
# Epoch 193/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0566 - accuracy: 0.9486
# Epoch 193: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 728ms/step - loss: 0.0566 - accuracy: 0.9486 - val_loss: 0.1381 - val_accuracy: 0.8661
# Epoch 194/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9463
# Epoch 194: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 754ms/step - loss: 0.0637 - accuracy: 0.9463 - val_loss: 0.1471 - val_accuracy: 0.8482
# Epoch 195/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9498
# Epoch 195: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 19s 720ms/step - loss: 0.0571 - accuracy: 0.9498 - val_loss: 0.1286 - val_accuracy: 0.8661
# Epoch 196/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9498
# Epoch 196: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 22s 827ms/step - loss: 0.0672 - accuracy: 0.9498 - val_loss: 0.1943 - val_accuracy: 0.8304
# Epoch 197/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9387
# Epoch 197: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 735ms/step - loss: 0.0692 - accuracy: 0.9387 - val_loss: 0.1370 - val_accuracy: 0.8527
# Epoch 198/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9451
# Epoch 198: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 776ms/step - loss: 0.0586 - accuracy: 0.9451 - val_loss: 0.1592 - val_accuracy: 0.8393
# Epoch 199/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9404
# Epoch 199: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 20s 755ms/step - loss: 0.0860 - accuracy: 0.9404 - val_loss: 0.1439 - val_accuracy: 0.8527
# Epoch 200/200
# 27/27 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9451
# Epoch 200: val_accuracy did not improve from 0.88839
# 27/27 [==============================] - 21s 772ms/step - loss: 0.0723 - accuracy: 0.9451 - val_loss: 0.1344 - val_accuracy: 0.8616

# %% [markdown]
# Loss / Accuracy vs Epoch

# %%
show_final_history(history)
model.save("model.h5")
print("Weights Saved")
# Out:
# Weights Saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Making predictions on the test images

# %%
test_pred = model.predict(test_images)
test_pred = np.argmax(test_pred,axis=1)
test_actual = np.argmax(test_labels,axis=1)

rnd_idx = random.sample(range(0,100),5)

class_labels = {i:class_name for (class_name,i) in class_name_labels.items()}

for i,idx in enumerate(rnd_idx):
    plt.imshow(test_images[idx])
    plt.title("Actual: {}\nPredicted: {}".format(class_labels[test_actual[idx]],class_labels[test_pred[idx]]))
    plt.grid(None)
    plt.show()
    pass
# Out:
# 4/4 [==============================] - 1s 268ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
