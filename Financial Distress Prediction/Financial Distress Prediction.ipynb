# %% [markdown]
# Predicting whether a given company is under financial distress or not based on time based data for different companies.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
from tensorflow.keras import optimizers, layers, models, losses, callbacks

# %% [markdown]
# Uploading data

# %%
df = pd.read_csv('https://cainvas-static.s3.amazonaws.com/media/user_data/cainvas-admin/Financial_Distress.csv')
df.head()
# Out:
#    Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0        1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1        1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2        1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3        1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4        2     1            1.357300  1.0623  0.107020  0.81460  0.83593
#
#          x5        x6       x7  ...      x74    x75     x76     x77   x78  \
# 0  0.060940  0.188270  0.52510  ...   85.437  27.07  26.102  16.000  16.0
# 1 -0.014080  0.181040  0.62288  ...  107.090  31.31  30.194  17.000  16.0
# 2  0.020476  0.044865  0.43292  ...  120.870  36.07  35.273  17.000  15.0
# 3  0.076037  0.091033  0.67546  ...   54.806  39.80  38.377  17.167  16.0
# 4  0.199960  0.047800  0.74200  ...   85.437  27.07  26.102  16.000  16.0
#
#    x79  x80       x81  x82  x83
# 0  0.2   22  0.060390   30   49
# 1  0.4   22  0.010636   31   50
# 2 -0.2   22 -0.455970   32   51
# 3  5.6   22 -0.325390   33   52
# 4  0.2   29  1.251000    7   27
#
# [5 rows x 86 columns]

# %%
# Analyze the data since there are many time periods for each company

pd.crosstab(df['Company'], df['Time'].sum())
# Out:
# col_0    27644
# Company
# 1            4
# 2           14
# 3            1
# 4           14
# 5           14
# ...        ...
# 418          2
# 419          3
# 420          3
# 421          6
# 422          8
#
# [422 rows x 1 columns]

# %% [markdown]
# Preprocessing Data

# %%
# One-hot encode input variables

df80 = pd.get_dummies(df['x80'], drop_first = True, prefix = '80')

for column in df80.columns:
    df[column] = df80[column]

df = df.drop(columns = ['x80'])

df
# Out:
#       Company  Time  Financial Distress      x1        x2       x3       x4  \
# 0           1     1            0.010636  1.2810  0.022934  0.87454  1.21640
# 1           1     2           -0.455970  1.2700  0.006454  0.82067  1.00490
# 2           1     3           -0.325390  1.0529 -0.059379  0.92242  0.72926
# 3           1     4           -0.566570  1.1131 -0.015229  0.85888  0.80974
# 4           2     1            1.357300  1.0623  0.107020  0.81460  0.83593
# ...       ...   ...                 ...     ...       ...      ...      ...
# 3667      422    10            0.438020  2.2605  0.202890  0.16037  0.18588
# 3668      422    11            0.482410  1.9615  0.216440  0.20095  0.21642
# 3669      422    12            0.500770  1.7099  0.207970  0.26136  0.21399
# 3670      422    13            0.611030  1.5590  0.185450  0.30728  0.19307
# 3671      422    14            0.518650  1.6148  0.176760  0.36369  0.18442
#
#             x5        x6       x7  ...  80_28  80_29  80_30  80_31  80_32  \
# 0     0.060940  0.188270  0.52510  ...  False  False  False  False  False
# 1    -0.014080  0.181040  0.62288  ...  False  False  False  False  False
# 2     0.020476  0.044865  0.43292  ...  False  False  False  False  False
# 3     0.076037  0.091033  0.67546  ...  False  False  False  False  False
# 4     0.199960  0.047800  0.74200  ...  False   True  False  False  False
# ...        ...       ...      ...  ...    ...    ...    ...    ...    ...
# 3667  0.175970  0.198400  2.22360  ...  False  False  False  False  False
# 3668  0.203590  0.189870  1.93820  ...  False  False  False  False  False
# 3669  0.193670  0.183890  1.68980  ...  False  False  False  False  False
# 3670  0.172140  0.170680  1.53890  ...  False  False  False  False  False
# 3671  0.169550  0.197860  1.58420  ...  False  False  False  False  False
#
#       80_33  80_34  80_35  80_36  80_37
# 0     False  False  False  False  False
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 3667  False  False  False  False   True
# 3668  False  False  False  False   True
# 3669  False  False  False  False   True
# 3670  False  False  False  False   True
# 3671  False  False  False  False   True
#
# [3672 rows x 121 columns]

# %% [markdown]
# Creating time-based dataframe

# %%
# Since this is a time based dataset, the features are appended to include values for previous timesteps of the same company group

# Defining the time window, that is, how many timesteps to include
time_window = 5

# Dataframes that hold rows grouped by company
df_company_grouped = df.groupby('Company')

# Column values affected by time - all except Company, Time, Financial Distress and x80 (the categorical variable that was one-hot encoded)
time_affected_columns = [c for c in df.columns if c[0] == 'x']    # Starts with x

# Final dataframe
df_final = pd.DataFrame()

# For each company
for company in df_company_grouped:
    # If the comapny has timesteps greater than or equal to the time window, else discard
    if time_window <= len(company[1]):
        # Skipping time_window-1 rows from the beginning, and looping to till the end
        for row_num in range(time_window, len(company[1])+1):
            # picking the time_window th row
            df_temp = company[1].iloc[row_num-1, :]
            # Appending values from time_window-1 rows before that
            for i in range(time_window-1):
                df_temp_i = company[1].iloc[row_num-1-i][time_affected_columns]    # Pick necessary columns
                df_temp = pd.concat([df_temp, df_temp_i], axis = 0)    # Append values

            df_temp = df_temp.to_frame().transpose()    # Series to DataFrame

            df_final = pd.concat([df_final, df_temp])    # Add as row to final dataframe

# Reset index
df_final = df_final.reset_index(drop = True)

# %% [markdown]
# One hot encode the target variables

# %%
# This is done based on the condition - healthy (0) if value > -0.5, else distressed (1)

df_final['Financial Distress'] = (df_final['Financial Distress']<-0.5).astype('int')
df_final['Financial Distress'].value_counts()
# Out:
# Financial Distress
# 0    2091
# 1      83
# Name: count, dtype: int64

# %% [markdown]
# Balancing the dataset

# %%
# With 5 timestep values in one row sample, resampling and training using this dataset without a time series split would be acceptable


# Separating into 2 dataframes, one for each class

df0 = df_final[df_final['Financial Distress'] == 0]
df1 = df_final[df_final['Financial Distress'] == 1]

print("Number of samples in:")
print("Class label 0 - ", len(df0))
print("Class label 1 - ", len(df1))

# Upsampling

df1 = df1.sample(1000, replace = True)    # replace = True enables resampling

print('\nAfter resampling - ')

print("Number of samples in:")
print("Class label 0 - ", len(df0))
print("Class label 1 - ", len(df1))

df = pd.concat([df1, df0])
# Out:
# Number of samples in:
# Class label 0 -  2091
# Class label 1 -  83
#
# After resampling -
# Number of samples in:
# Class label 0 -  2091
# Class label 1 -  1000

# %%
df['Financial Distress'].value_counts()
# Out:
# Financial Distress
# 0    2091
# 1    1000
# Name: count, dtype: int64

# %% [markdown]
# Defining the input and output columns

# %%
# Defining the input and output columns to separate the dataset in the later cells.

input_columns = list(df.columns)
input_columns.remove('Financial Distress')
output_columns = ['Financial Distress']

print("Number of input columns: ", len(input_columns))
#print("Input columns: ", ', '.join(input_columns))

print("Number of output columns: ", len(output_columns))
#print("Output columns: ", ', '.join(output_columns))
# Out:
# Number of input columns:  448
# Number of output columns:  1

# %% [markdown]
# Train-val-test split

# %%
# Splitting into train, val and test set -- 80-10-10 split

# First, an 80-20 split
train_df, val_test_df = train_test_split(df, test_size = 0.2)

# Then split the 20% into half
val_df, test_df = train_test_split(val_test_df, test_size = 0.5)

print("Number of samples in...")
print("Training set: ", len(train_df))
print("Validation set: ", len(val_df))
print("Testing set: ", len(test_df))
# Out:
# Number of samples in...
# Training set:  2472
# Validation set:  309
# Testing set:  310

# %%
# Splitting into X (input) and y (output)

Xtrain, ytrain = np.array(train_df[input_columns]), np.array(train_df[output_columns])

Xval, yval = np.array(val_df[input_columns]), np.array(val_df[output_columns])

Xtest, ytest = np.array(test_df[input_columns]), np.array(test_df[output_columns])

# %% [markdown]
# Scaling the values

# %%
# Each feature has a different range.
# Using min_max_scaler to scale them to values in the range [0,1].

min_max_scaler = MinMaxScaler()

# Fit on training set alone
Xtrain = min_max_scaler.fit_transform(Xtrain)

# Use it to transform val and test input
Xval = min_max_scaler.transform(Xval)
Xtest = min_max_scaler.transform(Xtest)

# %% [markdown]
# The Model

# %%
model = models.Sequential([
    layers.Dense(32, activation = 'relu', input_shape = Xtrain[0].shape),
    layers.Dense(16, activation = 'relu'),
    layers.Dense(8, activation = 'relu'),
    layers.Dense(1, activation = 'sigmoid')
])

cb = [callbacks.EarlyStopping(patience = 5, restore_best_weights = True)]
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                66848
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 67521 (263.75 KB)
# Trainable params: 67521 (263.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = optimizers.Adam(0.001), loss = losses.BinaryCrossentropy(), metrics = ['accuracy'])

history = model.fit(Xtrain, ytrain, validation_data = (Xval, yval), epochs = 256, callbacks = cb)
# Out:
# Epoch 1/256
# 78/78 [==============================] - 4s 19ms/step - loss: 0.4280 - accuracy: 0.7969 - val_loss: 0.3204 - val_accuracy: 0.8479
# Epoch 2/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2867 - accuracy: 0.8766 - val_loss: 0.2745 - val_accuracy: 0.8932
# Epoch 3/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2574 - accuracy: 0.8948 - val_loss: 0.2598 - val_accuracy: 0.9061
# Epoch 4/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2496 - accuracy: 0.8964 - val_loss: 0.2569 - val_accuracy: 0.8932
# Epoch 5/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2334 - accuracy: 0.9013 - val_loss: 0.3178 - val_accuracy: 0.8382
# Epoch 6/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.8972 - val_loss: 0.2935 - val_accuracy: 0.8803
# Epoch 7/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2394 - accuracy: 0.8977 - val_loss: 0.2391 - val_accuracy: 0.8997
# Epoch 8/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2188 - accuracy: 0.9061 - val_loss: 0.2687 - val_accuracy: 0.8997
# Epoch 9/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9078 - val_loss: 0.2325 - val_accuracy: 0.9094
# Epoch 10/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.2170 - accuracy: 0.9110 - val_loss: 0.2441 - val_accuracy: 0.9029
# Epoch 11/256
# 78/78 [==============================] - 1s 6ms/step - loss: 0.2075 - accuracy: 0.9118 - val_loss: 0.2299 - val_accuracy: 0.9061
# Epoch 12/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.2011 - accuracy: 0.9122 - val_loss: 0.2172 - val_accuracy: 0.9094
# Epoch 13/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.2068 - accuracy: 0.9118 - val_loss: 0.2278 - val_accuracy: 0.9094
# Epoch 14/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.2006 - accuracy: 0.9118 - val_loss: 0.2207 - val_accuracy: 0.9126
# Epoch 15/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.1974 - accuracy: 0.9175 - val_loss: 0.2206 - val_accuracy: 0.9126
# Epoch 16/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9110 - val_loss: 0.2332 - val_accuracy: 0.9029
# Epoch 17/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1887 - accuracy: 0.9195 - val_loss: 0.2697 - val_accuracy: 0.8964

# %%
model.compile(optimizer = optimizers.Adam(0.0001), loss = losses.BinaryCrossentropy(), metrics = ['accuracy'])

history1 = model.fit(Xtrain, ytrain, validation_data = (Xval, yval), epochs = 256, callbacks = cb)
# Out:
# Epoch 1/256
# 78/78 [==============================] - 2s 9ms/step - loss: 0.1908 - accuracy: 0.9159 - val_loss: 0.2149 - val_accuracy: 0.9126
# Epoch 2/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1871 - accuracy: 0.9175 - val_loss: 0.2149 - val_accuracy: 0.9191
# Epoch 3/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1850 - accuracy: 0.9171 - val_loss: 0.2123 - val_accuracy: 0.9126
# Epoch 4/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1833 - accuracy: 0.9191 - val_loss: 0.2130 - val_accuracy: 0.9159
# Epoch 5/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9175 - val_loss: 0.2165 - val_accuracy: 0.9126
# Epoch 6/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1823 - accuracy: 0.9183 - val_loss: 0.2128 - val_accuracy: 0.9191
# Epoch 7/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1806 - accuracy: 0.9175 - val_loss: 0.2126 - val_accuracy: 0.9126
# Epoch 8/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1811 - accuracy: 0.9191 - val_loss: 0.2085 - val_accuracy: 0.9159
# Epoch 9/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1812 - accuracy: 0.9195 - val_loss: 0.2101 - val_accuracy: 0.9159
# Epoch 10/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1787 - accuracy: 0.9191 - val_loss: 0.2082 - val_accuracy: 0.9159
# Epoch 11/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1788 - accuracy: 0.9219 - val_loss: 0.2067 - val_accuracy: 0.9159
# Epoch 12/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1781 - accuracy: 0.9171 - val_loss: 0.2112 - val_accuracy: 0.9126
# Epoch 13/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1785 - accuracy: 0.9248 - val_loss: 0.2082 - val_accuracy: 0.9159
# Epoch 14/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.9203 - val_loss: 0.2058 - val_accuracy: 0.9159
# Epoch 15/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.1746 - accuracy: 0.9203 - val_loss: 0.2095 - val_accuracy: 0.9126
# Epoch 16/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1740 - accuracy: 0.9219 - val_loss: 0.2044 - val_accuracy: 0.9126
# Epoch 17/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1719 - accuracy: 0.9187 - val_loss: 0.2013 - val_accuracy: 0.9223
# Epoch 18/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1732 - accuracy: 0.9219 - val_loss: 0.2001 - val_accuracy: 0.9223
# Epoch 19/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1700 - accuracy: 0.9215 - val_loss: 0.1999 - val_accuracy: 0.9223
# Epoch 20/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1692 - accuracy: 0.9199 - val_loss: 0.2011 - val_accuracy: 0.9191
# Epoch 21/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1678 - accuracy: 0.9231 - val_loss: 0.1971 - val_accuracy: 0.9256
# Epoch 22/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1735 - accuracy: 0.9239 - val_loss: 0.2046 - val_accuracy: 0.9126
# Epoch 23/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9268 - val_loss: 0.1993 - val_accuracy: 0.9159
# Epoch 24/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1657 - accuracy: 0.9244 - val_loss: 0.1930 - val_accuracy: 0.9256
# Epoch 25/256
# 78/78 [==============================] - 1s 10ms/step - loss: 0.1647 - accuracy: 0.9239 - val_loss: 0.1925 - val_accuracy: 0.9256
# Epoch 26/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.9235 - val_loss: 0.1969 - val_accuracy: 0.9256
# Epoch 27/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1625 - accuracy: 0.9231 - val_loss: 0.1920 - val_accuracy: 0.9159
# Epoch 28/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9288 - val_loss: 0.1883 - val_accuracy: 0.9256
# Epoch 29/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1601 - accuracy: 0.9256 - val_loss: 0.1922 - val_accuracy: 0.9159
# Epoch 30/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1618 - accuracy: 0.9288 - val_loss: 0.1913 - val_accuracy: 0.9223
# Epoch 31/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9276 - val_loss: 0.1883 - val_accuracy: 0.9159
# Epoch 32/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.1562 - accuracy: 0.9296 - val_loss: 0.1874 - val_accuracy: 0.9159
# Epoch 33/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.1589 - accuracy: 0.9280 - val_loss: 0.1949 - val_accuracy: 0.9256
# Epoch 34/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.1571 - accuracy: 0.9316 - val_loss: 0.1825 - val_accuracy: 0.9288
# Epoch 35/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.1555 - accuracy: 0.9333 - val_loss: 0.1809 - val_accuracy: 0.9159
# Epoch 36/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.1550 - accuracy: 0.9276 - val_loss: 0.1782 - val_accuracy: 0.9320
# Epoch 37/256
# 78/78 [==============================] - 1s 6ms/step - loss: 0.1529 - accuracy: 0.9292 - val_loss: 0.1744 - val_accuracy: 0.9288
# Epoch 38/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.1515 - accuracy: 0.9349 - val_loss: 0.1738 - val_accuracy: 0.9288
# Epoch 39/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.1484 - accuracy: 0.9385 - val_loss: 0.1771 - val_accuracy: 0.9223
# Epoch 40/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.
256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0885 - accuracy: 0.9701 - val_loss: 0.1120 - val_accuracy: 0.9612
# Epoch 100/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0883 - accuracy: 0.9697 - val_loss: 0.1116 - val_accuracy: 0.9612
# Epoch 101/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9689 - val_loss: 0.1103 - val_accuracy: 0.9547
# Epoch 102/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0874 - accuracy: 0.9705 - val_loss: 0.1116 - val_accuracy: 0.9612
# Epoch 103/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0845 - accuracy: 0.9721 - val_loss: 0.1084 - val_accuracy: 0.9644
# Epoch 104/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0853 - accuracy: 0.9729 - val_loss: 0.1099 - val_accuracy: 0.9644
# Epoch 105/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9749 - val_loss: 0.1069 - val_accuracy: 0.9644
# Epoch 106/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0831 - accuracy: 0.9745 - val_loss: 0.1067 - val_accuracy: 0.9644
# Epoch 107/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0829 - accuracy: 0.9713 - val_loss: 0.1268 - val_accuracy: 0.9547
# Epoch 108/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0851 - accuracy: 0.9697 - val_loss: 0.1072 - val_accuracy: 0.9579
# Epoch 109/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0808 - accuracy: 0.9749 - val_loss: 0.1153 - val_accuracy: 0.9547
# Epoch 110/256
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9749 - val_loss: 0.1044 - val_accuracy: 0.9644
# Epoch 111/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0785 - accuracy: 0.9769 - val_loss: 0.1032 - val_accuracy: 0.9644
# Epoch 112/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0798 - accuracy: 0.9741 - val_loss: 0.1082 - val_accuracy: 0.9644
# Epoch 113/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0791 - accuracy: 0.9773 - val_loss: 0.1028 - val_accuracy: 0.9644
# Epoch 114/256
# 78/78 [==============================] - 1s 6ms/step - loss: 0.0775 - accuracy: 0.9757 - val_loss: 0.1042 - val_accuracy: 0.9644
# Epoch 115/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0758 - accuracy: 0.9782 - val_loss: 0.1054 - val_accuracy: 0.9612
# Epoch 116/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0767 - accuracy: 0.9761 - val_loss: 0.1042 - val_accuracy: 0.9612
# Epoch 117/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0770 - accuracy: 0.9761 - val_loss: 0.1023 - val_accuracy: 0.9644
# Epoch 118/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9794 - val_loss: 0.1007 - val_accuracy: 0.9644
# Epoch 119/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0738 - accuracy: 0.9773 - val_loss: 0.1023 - val_accuracy: 0.9612
# Epoch 120/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0738 - accuracy: 0.9790 - val_loss: 0.0986 - val_accuracy: 0.9644
# Epoch 121/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9769 - val_loss: 0.1029 - val_accuracy: 0.9644
# Epoch 122/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0727 - accuracy: 0.9769 - val_loss: 0.1042 - val_accuracy: 0.9612
# Epoch 123/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9778 - val_loss: 0.0997 - val_accuracy: 0.9644
# Epoch 124/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0699 - accuracy: 0.9802 - val_loss: 0.0990 - val_accuracy: 0.9644
# Epoch 125/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0693 - accuracy: 0.9806 - val_loss: 0.0973 - val_accuracy: 0.9644
# Epoch 126/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0705 - accuracy: 0.9765 - val_loss: 0.0974 - val_accuracy: 0.9644
# Epoch 127/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9806 - val_loss: 0.0987 - val_accuracy: 0.9644
# Epoch 128/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 0.9782 - val_loss: 0.0966 - val_accuracy: 0.9644
# Epoch 129/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9806 - val_loss: 0.0960 - val_accuracy: 0.9644
# Epoch 130/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9810 - val_loss: 0.1047 - val_accuracy: 0.9644
# Epoch 131/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0679 - accuracy: 0.9806 - val_loss: 0.0974 - val_accuracy: 0.9644
# Epoch 132/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0661 - accuracy: 0.9802 - val_loss: 0.0940 - val_accuracy: 0.9644
# Epoch 133/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0643 - accuracy: 0.9818 - val_loss: 0.0941 - val_accuracy: 0.9644
# Epoch 134/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 0.9834 - val_loss: 0.0942 - val_accuracy: 0.9644
# Epoch 135/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9822 - val_loss: 0.0946 - val_accuracy: 0.9644
# Epoch 136/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0629 - accuracy: 0.9818 - val_loss: 0.0918 - val_accuracy: 0.9644
# Epoch 137/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9826 - val_loss: 0.0943 - val_accuracy: 0.9644
# Epoch 138/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0601 - accuracy: 0.9830 - val_loss: 0.0919 - val_accuracy: 0.9644
# Epoch 139/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0611 - accuracy: 0.9826 - val_loss: 0.0997 - val_accuracy: 0.9644
# Epoch 140/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0611 - accuracy: 0.9806 - val_loss: 0.0904 - val_accuracy: 0.9644
# Epoch 141/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9822 - val_loss: 0.0937 - val_accuracy: 0.9644
# Epoch 142/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0585 - accuracy: 0.9826 - val_loss: 0.0910 - val_accuracy: 0.9644
# Epoch 143/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 0.9834 - val_loss: 0.0946 - val_accuracy: 0.9644
# Epoch 144/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9834 - val_loss: 0.0890 - val_accuracy: 0.9644
# Epoch 145/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9842 - val_loss: 0.0889 - val_accuracy: 0.9644
# Epoch 146/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9834 - val_loss: 0.0896 - val_accuracy: 0.9644
# Epoch 147/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 0.9846 - val_loss: 0.0881 - val_accuracy: 0.9644
# Epoch 148/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0560 - accuracy: 0.9842 - val_loss: 0.0888 - val_accuracy: 0.9644
# Epoch 149/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9846 - val_loss: 0.0904 - val_accuracy: 0.9644
# Epoch 150/256
# 78/78 [==============================] - 1s 6ms/step - loss: 0.0534 - accuracy: 0.9854 - val_loss: 0.0870 - val_accuracy: 0.9644
# Epoch 151/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0531 - accuracy: 0.9858 - val_loss: 0.0868 - val_accuracy: 0.9644
# Epoch 152/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0533 - accuracy: 0.9858 - val_loss: 0.0882 - val_accuracy: 0.9644
# Epoch 153/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0527 - accuracy: 0.9846 - val_loss: 0.0882 - val_accuracy: 0.9741
# Epoch 154/256
# 78/78 [==============================] - 1s 7ms/step - loss: 0.0557 - accuracy: 0.9842 - val_loss: 0.0987 - val_accuracy: 0.9741
# Epoch 155/256
# 78/78 [==============================] - 0s 6ms/step - loss: 0.0545 - accuracy: 0.9858 - val_loss: 0.0851 - val_accuracy: 0.9644
# Epoch 156/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9875 - val_loss: 0.0866 - val_accuracy: 0.9644
# Epoch 157/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9862 - val_loss: 0.0884 - val_accuracy: 0.9741
# Epoch 158/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 0.9867 - val_loss: 0.0870 - val_accuracy: 0.9741
# Epoch 159/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.9862 - val_loss: 0.0846 - val_accuracy: 0.9741
# Epoch 160/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 0.0844 - val_accuracy: 0.9644
# Epoch 161/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 0.9883 - val_loss: 0.0879 - val_accuracy: 0.9676
# Epoch 162/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9875 - val_loss: 0.0849 - val_accuracy: 0.9741
# Epoch 163/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9875 - val_loss: 0.0832 - val_accuracy: 0.9644
# Epoch 164/256
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0471 - accuracy: 0.9887 - val_loss: 0.0865 - val_accuracy: 0.9741
# Epoch 165/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9867 - val_loss: 0.0853 - val_accuracy: 0.9741
# Epoch 166/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9891 - val_loss: 0.0864 - val_accuracy: 0.9644
# Epoch 167/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9887 - val_loss: 0.0897 - val_accuracy: 0.9741
# Epoch 168/256
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0450 - accuracy: 0.9895 - val_loss: 0.0862 - val_accuracy: 0.9741

# %%
model.evaluate(Xtest, ytest)
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9677
# [0.10353994369506836, 0.9677419066429138]

# %%
ypred = (model.predict(Xtest)>0.5).astype('int')

cm = confusion_matrix(ytest, ypred)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

fig = plt.figure(figsize = (4, 4))
ax = fig.add_subplot(111)

for i in range(cm.shape[1]):
    for j in range(cm.shape[0]):
        ax.text(j, i, format(cm[i, j], '.2f'), horizontalalignment="center", color="black")

_ = ax.imshow(cm, cmap=plt.cm.Blues)
ax.set_xticks(range(2))
ax.set_yticks(range(2))
ax.set_xticklabels(range(2))
ax.set_yticklabels(range(2))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 10/10 [==============================] - 0s 5ms/step

# %% [markdown]
# Plotting the metrics

# %%
def plot(history1, history2, variable1, variable2):
    # combining metrics from both trainings
    var1_history = history1[variable1]
    var1_history.extend(history2[variable1])

    var2_history = history1[variable2]
    var2_history.extend(history2[variable2])

    # plotting them
    plt.plot(range(len(var1_history)), var1_history)
    plt.plot(range(len(var2_history)), var2_history)
    plt.legend([variable1, variable2])
    plt.title(variable1)

# %%
plot(history.history, history1.history, "accuracy", 'val_accuracy')

# %%
plot(history.history, history1.history, "loss", 'val_loss')

# %% [markdown]
# Prediction

# %%
# Pick random test data sample from one batch
x = random.randint(0, len(Xtest) - 1)

output = model.predict(Xtest[x].reshape(1, -1))[0][0]
pred = (output>0.5).astype('int')
print("Predicted: ", pred, "(", output, "-->", pred, ")")

print("True: ", ytest[x][0])
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Predicted:  1 ( 0.99588996 --> 1 )
# True:  1

# %%
model.save('financial_distress_prediction.h5')

# %%
# pick random test data sample from one batch
x = random.randint(0, len(Xtest) - 1)

np.savetxt('sample.data', Xtest[x])    # xth sample into text file

# run exe with input
# !financial_distress_prediction_deepC/financial_distress_prediction.exe sample.data

# show predicted output
nn_out = np.loadtxt('deepSea_result_1.out')

pred = (nn_out>0.5).astype('int')
print("Predicted: ", pred, "(", nn_out, "-->", pred, ")")

print("True: ", ytest[x][0])
